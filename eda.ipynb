# %% [markdown]
# # Mushroom Classification
#
# ## Project Topic
#
# TODO:
# The goal of this project is to build an accurate model for predicting if a mushroom is edible or not. This is a classification problem. The motivation of this project....
#
# ## Data
#
# TODO:
# Mushroom [Dataset]. (1981). UCI Machine Learning Repository. https://doi.org/10.24432/C5959T.

# %%
from ucimlrepo import fetch_ucirepo

mushroom = fetch_ucirepo(id=73)

# Save data locally for availability
mushroom.data.features.to_csv('data/features.csv')
mushroom.data.targets.to_csv('data/targets.csv')

# %% [markdown]
# ## Data Cleaning
#
# TODO:

# %%
feat = mushroom.data.features
feat.describe()
# Out:
#        cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count       8124        8124      8124    8124  8124            8124
# unique         6           4        10       2     9               2
# top            x           y         n       f     n               f
# freq        3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color stalk-shape  ...  \
# count          8124      8124       8124        8124  ...
# unique            2         2         12           2  ...
# top               c         b          b           t  ...
# freq           6812      5612       1728        4608  ...
#
#        stalk-surface-below-ring stalk-color-above-ring stalk-color-below-ring  \
# count                      8124                   8124                   8124
# unique                        4                      9                      9
# top                           s                      w                      w
# freq                       4936                   4464                   4384
#
#        veil-type veil-color ring-number ring-type spore-print-color  \
# count       8124       8124        8124      8124              8124
# unique         1          4           3         5                 9
# top            p          w           o         p                 w
# freq        8124       7924        7488      3968              2388
#
#        population habitat
# count        8124    8124
# unique          6       7
# top             v       d
# freq         4040    3148
#
# [4 rows x 22 columns]
